# %% [markdown]
# # Final Project 4 (Clustering) - Credit Card Dataset for Clustering
#
# **Dataset source:** https://www.kaggle.com/datasets/arjunbhasin2013/ccdata
#
# **About this dataset**
#
# Data ini berisi transaksi pengguna kartu kredit sebanyak 9000 orang selama 6 bulan. Data
# ini memiliki 18 atribut.
#
# **Attribute Information:**
# 1. CUSTID - Identification of Credit Card holder (Categorical)
# 2. BALANCE - Balance amount left in their account to make purchases (
# 3. BALANCEFREQUENCY - How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# 4. PURCHASES - Amount of purchases made from account
# 5. ONEOFFPURCHASES - Maximum purchase amount done in one-go
# 6. INSTALLMENTSPURCHASES - Amount of purchase done in installment
# 7. CASHADVANCE - Cash in advance given by the user
# 8. PURCHASESFREQUENCY - How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# 9. ONEOFFPURCHASESFREQUENCY - How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# 10. PURCHASESINSTALLMENTSFREQUENCY - How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# 11. CASHADVANCEFREQUENCY - How frequently the cash in advance being paid
# 12. CASHADVANCETRX - Number of Transactions made with "Cash in Advance"
# 13. PURCHASESTRX - Number of purchase transactions made
# 14. CREDITLIMIT - Limit of Credit Card for user
# 15. PAYMENTS - Amount of Payment done by user
# 16. MINIMUM_PAYMENTS - Minimum amount of payments made by user
# 17. PRCFULLPAYMENT - Percent of full payment paid by user
# 18. TENURE - Tenure of credit card service for user
#
# ## Clustering
#
# Clustering merupakan salah satu algoritma yang bekerja dengan cara mengelompokkan obyek-obyek data (pola, entitas, kejadian, unit,hasil observasi) ke dalam cluster tertentu (Xu and Wunsch,2009). Dengan kata lain algoritma Clustering melakukan pemisahan/ pemecahan/ segmentasi data ke dalam sejumlah kelompok (cluster) menurut karakteristik tertentu. Dalam klasifikasi unsupervised (clustering/segmentation/partitioning) menggunakan data yang tidak memilki label/Target seperti pada klasifikasi supervised, namun dari atribut yang ada akan dikelompokkan menurut karakteristiknya.
#
# Dalam prakteknya, clustering membantu mengidentifikasi dua kualitas data:
# - Meaningfull, Meaningful clusters expand domain knowledge. hanya sebagai proses awal untuk kemudian dilanjutkan dengan pekerjaan seperti summarization(rata-rata,standar deviasi), pelabelan kelas untuk setiap kelompok sehingga dapat digunakan sebagai data training dalam klasifikasi supervised.
# - usefull, Useful clusters berfungsi sebagai intermediate step pada data pipeline*.
#
# Clustering dapat dibedakan menurut struktur kelompok ,keanggotaan data dalam kelompok, dan kekompakan data dalam kelompok.
# Menurut struktur kelompok clustering dibagi menjadi dua yaitu hierarchical dan partitioning.
# - HIERARCHICAL:menemukan klaster yang berurutan menggunakan klaster yang telah ditetapkan sebelumnya
#     • aglomerative (bottom-up): mulai dengan setiap elemen dalam cluster terpisah dan gabungkan mereka sesuai dengan properti yang diberikan.
#     • divisive (top‐down) : merupakan proses kebalikan dari agglomerative
#
# - PARTITIONAL: biasanya menentukan semua cluster sekaligus.mengelompokkan datapointkedalam k klaster tanpa struktur hirarki( Xu & Wunsch, 2009). Partitioning algorithm memisahkan (mem-partisi) titik-titik atau objek data menjadi K kelompok/ cluster, sedemikian rupa sehingga titik-titik dalam satu cluster memiliki karakteristik se-homogen mungkin, dan karakteristik antar cluster se-heterogen mungkin. Beberapa algoritma yang termasuk dalam metode ini adalah K-Means, K-Medoid, DBSCAN, Mixture-Based Density,Graph Theory-Based Clustering,Fuzzy Clustering.
#
# Dalam menentukan jumlah cluster dilakukan menggunakan Metode Elbow dan Shilouette Score.
#
# #### Elbow Method
# Metode Elbow merupakan suatu metode yang digunakan untuk menghasilkan informasi dalam menentukan jumlah cluster terbaik dengan cara melihat persentase hasil perbandingan antara jumlah cluster yang akan membentuk siku pada suatu titik.
#
# #### Shilouette Score
# Metode Shilouette merupakan metode evaluasi cluster yang menggabungkan metode cohessian dan separation. Cohessian diukur dengan menghitung seluruh objek yang terdapat dalam sebuah cluster dan separation diukur dengan menghitung jarak rata-rata setiap objek dalam sebuah cluster dengan cluster terdekatnya.
#
#
# **Dalam Analisis kali ini akan dilakukan clustering menggunakan algoritma K-Means, PCA, K-Medoid dan DBSCAN**
#
# ![image.png](attachment:image.png)
#
# ### K-Means Clustering
#
# Dalam machine-learning dan statistic K-Means merupakan metode analisis kelompok yang mengarah pada pembagian N obyek pengamatan ke dalam K kelompok (cluster), dimana setiap obyek dimiliki oleh sebuah kelompok dengan mean (rata-rata) dan metode ini mencoba untuk menemukan pusat dari kelompok (centroid) dalam data sebanyak iterasi perbaikan yang dilakukan. Metode ini berusaha
# membagi data kedalam kelompok sehingga data yang berkarakteristik sama dimasukkan ke dalam satu kelompok sementara data yang berkarakteristik berbeda dimasukkan dalam kelompok yang lain.
#
#
# ### PCA (Principal Component Analysis)
#    Principal Component Analysis (PCA) adalah teknik *unsupervised Machine Learning* yang mencoba menurunkan serangkaian fitur berdimensi rendah dari rangkaian yang jauh lebih besar sambil tetap mempertahankan varians sebanyak mungkin. PCA sangat berguna untuk menyimpan informasi sekaligus mereduksi dimensi data. Namun, kita perlu memastikan bahwa data sudah diskalakan (scaled) dengan benar untuk mendapatkan PCA yang berguna.
#
# ### K-Medoid Clustering
# K-Medoids atau Partitioning Around Method (PAM) adalah metode cluster non hirarki yang merupakan varian dari metode K-Means.
# K-Medoids hadir untuk mengatasi kelemahan K-Means yang sensitif terhadap outlier karena suatu objek dengan suatu nilai yang besar mungkin secara substansial menyimpang dari distribusi data (Jiawei & Kamber, 2006). Hal ini didasarkan pada penggunaan medoids bukan dari pengamatan mean yang dimiliki oleh setiap cluster, dengan tujuan mengurangi sensitivitas dari partisi sehubungan dengan nilai ekstrim yang ada dalam dataset (Vercellis, 2009)
#
# ### DBSCAN
# Algoritma DBSCAN adalah sebuah algoritma clustering yang dikembangkan berdasarkan tingkat kerapatan data (density-based). Dimana algoritma ini menumbuhkan daerah yang memiliki kerapatan tinggi menjadi cluster-cluster, dan menemukan cluster-cluster tersebut pada bentuk bebas dalam sebuah ruang database dengan memanfaatkan noise. DBSCAN sering diterapkan pada data yang banyak mengandung noise, hal ini dikarenakan DBSCAN tidak akan memasukkan data yang dianggap noise kedalam cluster manapun.
#
# DBSCAN memerlukan dua parameter input sebelum melakukan proses clustering yaitu epsilon (eps) dan minimum points (minPts). Epsilon merupakan jarak maksimal antara dua data dalam satu cluster yang diizinkan, dan minimum points adalah banyaknya data minimal dalam jarak epsilon agar terbentuk suatu cluster. Metode jarak yang digunakan dalam DBSCAN adalah jarak Euclidian.

# %% [markdown]
# ## Import Pustaka yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %matplotlib inline

# %% [markdown]
# ## Data Loading

# %%
# membaca dataset

df = pd.read_csv('CC GENERAL.csv')
pd.set_option('display.max_columns',None)
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# Berdasarkan keterangan di atas, diketahui bahwa dataset ini terdiri dari 8950 baris dan 18 kolom. Terdapat 14 kolom yang memiliki tipe *float*, 3 kolom dengan tipe *integer*, dan 1 kolom dengan tipe *object*.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.describe().T.style.background_gradient(cmap = 'icefire')
# Out:
# <style type="text/css">
# #T_6cbd5_row0_col0, #T_6cbd5_row1_col0, #T_6cbd5_row2_col0, #T_6cbd5_row3_col0, #T_6cbd5_row4_col0, #T_6cbd5_row5_col0, #T_6cbd5_row6_col0, #T_6cbd5_row7_col0, #T_6cbd5_row8_col0, #T_6cbd5_row9_col0, #T_6cbd5_row10_col0, #T_6cbd5_row11_col0, #T_6cbd5_row12_col0, #T_6cbd5_row12_col1, #T_6cbd5_row12_col2, #T_6cbd5_row12_col3, #T_6cbd5_row12_col4, #T_6cbd5_row12_col5, #T_6cbd5_row12_col6, #T_6cbd5_row13_col0, #T_6cbd5_row14_col7, #T_6cbd5_row15_col0, #T_6cbd5_row16_col0 {
#   background-color: #ffd4ac;
#   color: #000000;
# }
# #T_6cbd5_row0_col1 {
#   background-color: #3f3d74;
#   color: #f1f1f1;
# }
# #T_6cbd5_row0_col2 {
#   background-color: #3b2127;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# **interpretasi :** Dari hasil di atas dapat diketahui summerize data (statistik deskriptif) dari dataset Credit Card.

# %% [markdown]
# ## Data Prepocessing
# ### Data Cleaning : Menangani Missing Value
#
# akan dilakukan proses cleaning data. langkah pertama dilakukan pengecekan missing value.

# %%
# Memeriksa apakah terdapat missing values setiap kolom pada data
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Let's see if we have any missing data, luckily we don't!
sns.heatmap(df.isnull(),yticklabels=False,cmap='Blues',cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **interpretasi :** dari output di atas dapat diketahui bahwa pada dataset credit card terdapat 2 atribut yang memiliki missing value yaitu atribut CREDIT_LIMIT sebanyak 1 data dan MINIMUM_PAYMENTS sebanyak 313 data. Selanjutnya, akan dilihat persentase data hilang dari kedua atribut tersebut.

# %%
(df.isnull().sum()/df['CUST_ID'].count())*100
# Out:
# CUST_ID                             0.000000
# BALANCE                             0.000000
# BALANCE_FREQUENCY                   0.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.011173
# PAYMENTS                            0.000000
# MINIMUM_PAYMENTS                    3.497207
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# dtype: float64

# %% [markdown]
# **interpretasi :**  Dari output di atas dapat dilihat persentase dari feture yang terdapat missing value cukup rendah, yaitu untuk feature CREDIT_LIMIT sebesar 0.01% dan untuk MINIMUM_PAYMENTS sebesar 3.49% maka akan dilakukan pengisian missing value dengan nilai "median" dari masing-masing feature tersebut.
#
# Selanjutnya dilakukan impute untuk atribut yang memiliki missing value menggunakan SimpleImputer.

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')

X = df['MINIMUM_PAYMENTS'].values.reshape(-1,1)
X = imputer.fit_transform(X) 

df['MINIMUM_PAYMENTS_NEW'] = X

# %%
X2 = df['CREDIT_LIMIT'].values.reshape(-1,1)
X2 = imputer.fit_transform(X2) 

df['CREDIT_LIMIT_NEW'] = X2

# %% [markdown]
# **interpretasi :** setelah dilakukan imputasi untuk missing value dan terdapat atribut baru untuk CREDIT_LIMIT dan MINIMUM_PAYMENTS menjadi CREDIT_LIMIT_NEW dan MINIMUM_PAYMENTS_NEW maka dilakukan penghapusan kolom atribut tersebut.

# %%
df = df.drop(['CREDIT_LIMIT','MINIMUM_PAYMENTS'],axis = 1)

# %% [markdown]
# selanjutnya dilakukan pengecekan missing value kembali untuk memastikan tidak terdapat data hilang dari dataset yang akan dianalisis.

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='Blues',yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **interpretasi :** Dapat dilihat dari output di atas bahwa sudah tidak terdapat missing value dalam dataset credit card.
#
# Selanjutnya akan  dilakukan penghapusan feature CUST_ID karena tidak diperlukan untuk proses analisis clustering yang akan dilakukan.

# %%
df = df.drop(['CUST_ID'], axis = 1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
df.shape
# Out:
# (8950, 17)

# %% [markdown]
# ## Visualisasi
#
# #### Univariate Analysis

# %%
def feat_plot(feature):
    plt.figure(figsize=(16, 6))
    plt.subplot(1, 3, 1)
    feature.plot(kind = 'hist')
    plt.title(f'{feature.name}')
    
    #mean = feature.describe().mean()
    plt.subplot(1, 3, 2)
    mu, sigma = scipy.stats.norm.fit(feature)
    sns.distplot(feature) 
    #plt.legend({'--': mu, 'sigma': sigma})
    plt.axvline(mu, linestyle = '--', color = 'green', )
    plt.axvline(sigma, linestyle = '--', color = 'red')
    plt.title(f'{feature.name} distribution')
    
    plt.subplot(1, 3, 3)
    feature.plot(kind = 'box')
    plt.title(f'{feature.name}')
    plt.show()

# %%
num_feature = df.select_dtypes(exclude='object')

for i in num_feature.columns:
    feat_plot(num_feature[i])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **interpretasi :** Dari output di atas dapat dilihat terdapat 3 gambar yang terbentuk, dengan susunan dari kiri yaitu :
# - visualisasi Histogram untuk data di masing-masing atribut
# - visualisasi grafik distribusi frekuensi untuk data di masing-masing atribut
# - Visualisasi Barplot untuk data di masing-masing atribut
#
# **VISUALISASI MENGGUNAKAN SCATTER PLOT**

# %%
sns.regplot(data = df, y = 'CREDIT_LIMIT_NEW', x = 'PAYMENTS')
# Out:
# <AxesSubplot:xlabel='PAYMENTS', ylabel='CREDIT_LIMIT_NEW'>

# %% [markdown]
# **interpretasi :**  Dari output di atas dapat dilihat bahwa sebaran atribut CREDIT_LIMIT_NEW dan PAYMENTS membentuk sebaran yang cukup linear.

# %%
sns.regplot(data = df, y = 'BALANCE_FREQUENCY', x = 'BALANCE')
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='BALANCE_FREQUENCY'>

# %% [markdown]
# **interpretasi :**  Dari output di atas dapat dilihat bahwa sebaran atribut BALANCE_FREQUENCY dan BALANCE membentuk sebaran yang cukup linear.

# %% [markdown]
# #### Find the Correlation

# %%
plt.figure(figsize=(20,15))
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot = True, vmin = -1, vmax = 1, cmap = 'icefire', mask = matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **interpretasi :**  dari heatmap yang terbentuk, dapat dilihat bahwa ada korelasi positif yang tinggi antara ONEOFF_PURCHASES dan PURCHASES sebesar 0.92, PURCHASES_INSTALLMENTS_FREQUENCY dan PURCHASES_FREQUENCY sebesar 0.86, serta CASH_ADVANCE_TRX dan CASH_ADVANCE_FREQUENCE sebesar 0.8.
#
# dikarenakan atribut ONEOFF_PURCHASES dan PURCHASES,  PURCHASES_INSTALLMENTS_FREQUENCY dan PURCHASES_FREQUENCY, serta CASH_ADVANCE_TRX dan CASH_ADVANCE_FREQUENCE memiliki korelasi yang tinggi maka akan dilakukan penghapusan salah satu atribut dari atribut yang berkorelasi tinggi tersebut, yaitu atribut ONEOFF_PURCHASES, PURCHASES_FREQUENCY, dan CASH_ADVANCE_TRX.

# %%
df = df.drop(['ONEOFF_PURCHASES','PURCHASES_FREQUENCY','CASH_ADVANCE_TRX'], axis = 1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  4   CASH_ADVANCE                      8950 non-null   float64
#  5   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  6   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  7   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  8   PURCHASES_TRX                     8950 non-null   int64
#  9   PAYMENTS                          8950 non-null   float64
#  10  PRC_FULL_PAYMENT                  8950 non-null   float64
# ...

# %% [markdown]
# ### HANDLING OUTLIERS

# %%
plt.figure(figsize=(30,30))
for idx,val in enumerate(df):
    plt.subplot(6,3,idx+1)
    sns.boxplot(x=val,data=df)

# %% [markdown]
# **interpretasi :** Dari output di atas dapat dilihat bahwa data tersebut mengandung banyak outlier yang harus ditangani. Akan dilakukan trasformasi untuk atribut yang memiliki tipe data float menggunakan log karena ketika dilihat dari boxplot yang terbentuk terlihat sebaran data pada masing-masing atribut mendekati kuartil bawah.
#
#
# ### Transformasi data
# Periksa the skewed values and transform them

# %%
float_columns = [x for x in df.columns if x not in  ['CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'TENURE']]

# %%
skew_columns = (df[float_columns].skew().sort_values(ascending=False))
skew_columns = skew_columns.loc[skew_columns > 0.75]
skew_columns
# Out:
# MINIMUM_PAYMENTS_NEW          13.852446
# PURCHASES                      8.144269
# INSTALLMENTS_PURCHASES         7.299120
# PAYMENTS                       5.907620
# CASH_ADVANCE                   5.166609
# BALANCE                        2.393386
# PRC_FULL_PAYMENT               1.942820
# CASH_ADVANCE_FREQUENCY         1.828686
# ONEOFF_PURCHASES_FREQUENCY     1.535613
# CREDIT_LIMIT_NEW               1.522636
# dtype: float64

# %%
# Perform a Log transform on skewed columns
for col in skew_columns.index.tolist():
    df[col] = np.log1p(df[col])

# %% [markdown]
# ### Perform feature Scaling (Standarisasi)
#
# Akan dilakukan standarisasi menggunakan StandardScaler.

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Standardizing the data
scaler = StandardScaler()
scaler.fit(df)
scaled_features = scaler.transform(df)
data_scaled = pd.DataFrame(scaled_features,columns = df.columns)
data_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 0 -1.205218          -0.249434  -0.113532                0.394480
# 1  0.948918           0.134325  -1.679855               -1.087454
# 2  0.824993           0.518084   0.600727               -1.087454
# 3  0.624653          -1.016953   0.827499               -1.087454
# 4  0.271260           0.518084  -0.708481               -1.087454
#
#    CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0     -0.930733                   -0.732480                         -0.707313
# 1      1.528788                   -0.732480                         -0.916995
# 2     -0.930733                    2.466762                         -0.916995
# 3      0.564372                   -0.363042                         -0.916995
# 4     -0.930733                   -0.363042                         -0.916995
#
#    CASH_ADVANCE_FREQUENCY  PURCHASES_TRX  PAYMENTS  PRC_FULL_PAYMENT   TENURE  \
# ...

# %% [markdown]
# ## Menentukan Jumlah Cluster Menggunakan Metode Elbow dan Shilouette Score

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Kurva Elbow

# %%
# Membuat plot kurva Elbow
scores_1 = []

range_values = range(1,10)
for i in range_values:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(data_scaled)
    scores_1.append(kmeans.inertia_)
plt.plot(scores_1, 'bx-')
plt.style.use('ggplot')
plt.title('Kurva Elbow')
plt.xlabel('Numer of Clusters')
plt.ylabel('Scores') 
plt.show()

# %% [markdown]
# **Interpretasi:** Berdasarkan kurva di atas, jumlah cluster yang palig optimal adalah 2 karena titk 2 membentuk siku kurva

# %% [markdown]
# ### Shiloutte Score

# %%
from sklearn.metrics import silhouette_score

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice we start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans_3 = KMeans(n_clusters=k)
    kmeans_3.fit(data_scaled)
    score = silhouette_score(data_scaled, kmeans_3.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.title('Kurva Shilloutte Score')
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %% [markdown]
# **Interpretasi:** Jumlah cluster yang paling optimal berdasarkan shilloutte score adalah 2, karena 2 merupakan nilai yang paling tinggi

# %% [markdown]
# ## Pendefinisian Model

# %%
X = data_scaled.copy()

# %%
# Mendefinisikan model kmeans dengan jumlah klaster sebanyak 2
kmeans= KMeans(n_clusters=2, n_init=10, init= 'k-means++', algorithm='full', max_iter=300)

# %% [markdown]
# ## Pelatihan Model

# %%
# Fitting data scaled dengan model K-means
kmeans.fit(X)
labels= kmeans.labels_

# %%
kmeans.cluster_centers_.shape
# Terdapat 5 klaster berdasarkan 14 kolom
# Out:
# (2, 14)

# %% [markdown]
# ## Evaluasi Model

# %% [markdown]
# ### Interpretasi karakteristik masing-masing klaster

# %%
# Rata-rata nilai masing-masing kolom berdasarkan clusternya
cluster_centers = pd.DataFrame(data = kmeans.cluster_centers_,columns = [df.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY PURCHASES INSTALLMENTS_PURCHASES CASH_ADVANCE  \
# 0  0.553512          0.172463 -0.809815              -0.721766     0.982002
# 1 -0.377154         -0.117513  0.551794               0.491799    -0.669119
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                  -0.371840                        -0.666568
# 1                   0.253365                         0.454188
#
#   CASH_ADVANCE_FREQUENCY PURCHASES_TRX  PAYMENTS PRC_FULL_PAYMENT    TENURE  \
# 0               0.842225     -0.431037  0.060363        -0.419483 -0.133979
# 1              -0.573878      0.293701 -0.041130         0.285828  0.091291
#
#   MINIMUM_PAYMENTS_NEW CREDIT_LIMIT_NEW
# 0             0.431481         0.002271
# 1            -0.294004        -0.001548

# %%
# Membuat kolom keterangan cluster pada dataframe
df_clusters = pd.concat([df, pd.DataFrame({'cluster':labels})], axis=1)
df_clusters.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 0  3.735304           0.818182   4.568506                4.568506
# 1  8.071989           0.909091   0.000000                0.000000
# 2  7.822504           1.000000   6.651791                0.000000
# 3  7.419183           0.636364   7.313220                0.000000
# 4  6.707735           1.000000   2.833213                0.000000
#
#    CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0      0.000000                    0.000000                          0.083333
# 1      8.770896                    0.000000                          0.000000
# 2      0.000000                    0.693147                          0.000000
# 3      5.331694                    0.080042                          0.000000
# 4      0.000000                    0.080042                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  PURCHASES_TRX  PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# ...

# %%
# Interpretasi cluster yang terbentuk
for c in df_clusters:
    grid= sns.FacetGrid(df_clusters, col='cluster')
    grid.map(plt.hist, c)

# %%
# Jumlah observasi dalam masing-masing cluster

count_cluster = df_clusters.groupby('cluster').count()
count_cluster['BALANCE']
# Out:
# cluster
# 0    3630
# 1    5320
# Name: BALANCE, dtype: int64

# %% [markdown]
# **Interpretasi:**
#
# *Cluster 0:*
# - Jumlah pengguna sebanyak 3630
# - Nilai balance frequency lebih kecil daripada cluster 1, yang berarti saldo pengguna lebih jarang diupdate
# - Pengguna lebih jarang melakukan purchases atau pembelian bahkan lebih 2000 pengguna tidak melakukan pembelian
# - Jumlah pengguna yang melakukan payment atau pembayaran kartu kredit adalah kurang dari 1300 pengguna
# - Pengguna yang membayar tenure berjumlah kurang lebih 2500 pengguna
# - Credit limit pengguna lebih rendah daripada cluster 1, rata - rata ada diangka 800
#
# *Cluster 1:*
# - Jumlah pengguna sebanyak 5320, lebih banyak daripada cluster 0
# - Nilai balance frequency lebih besar daripada cluster 0
# - Pengguna sering melakukan purchases atau pembelian
# - Jumlah pengguna yang melakukan payment atau pembayaran kartu kredit adalah kurang dari 2000 pengguna
# - Pengguna yang membayar tenure berjumlah kurang lebih 5000 pengguna
# - Credit limit pengguna lebih tinggi daripada cluster 0, rata - rata ada diangka 1000 ke atas

# %% [markdown]
# ## Principal Component Analysis (PCA)

# %%
from sklearn.decomposition import PCA

# %%
# Membuat PCA dengan jumlah komponen  kolom
pca = PCA(n_components=14)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# array([[ 0.32195413, -2.26271834, -0.77528775, ...,  0.06707985,
#          0.3281731 ,  0.77597662],
#        [-2.74901897,  1.02933313,  1.01090674, ...,  0.07635272,
#         -0.0332979 , -0.0389493 ],
#        [ 0.2277167 ,  1.12377208,  1.7949288 , ..., -0.44047691,
#          0.04921546, -0.30550675],
#        ...,
#        [ 1.07118717, -3.15130394, -2.01473808, ..., -0.20869912,
#         -0.253635  ,  0.26066614],
#        [-1.59248409, -4.10907426, -1.15124969, ..., -0.37512218,
#         -0.21072961,  0.5588281 ],
#        [-0.8575344 , -1.58407504, -0.02822131, ...,  0.19295829,
#          0.08525515, -0.36769345]])

# %%
# Membuat dataframe dari komponen utama yang sudah dibuat
cols = ["Feature "+str(i) for i in range(principal_components.shape[1])]
df_pca_components = pd.DataFrame(data = principal_components, columns = cols)
df_pca_components.head()
# Out:
#    Feature 0  Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  \
# 0   0.321954  -2.262718  -0.775288  -1.027829   0.090916  -0.317261
# 1  -2.749019   1.029333   1.010907   0.203129  -1.365147  -0.214327
# 2   0.227717   1.123772   1.794929  -1.537572   2.122744  -0.323820
# 3  -1.161755  -1.552297   0.015311  -1.160487   1.549467   2.157392
# 4  -0.884173  -1.055298  -0.175703  -1.474068   0.456975  -1.351414
#
#    Feature 6  Feature 7  Feature 8  Feature 9  Feature 10  Feature 11  \
# 0   0.505056  -0.234677  -0.317619   0.117580    0.381666    0.067080
# 1  -0.484743  -0.088956   0.701881   0.107171   -0.482445    0.076353
# 2  -0.600875   0.245617  -0.350391  -0.247185   -0.303061   -0.440477
# 3  -0.662177   2.470344  -0.228542  -1.020384    0.236562    1.723920
# 4   0.026808  -0.447440   0.170506   0.477651    0.277936   -0.085034
#
#    Feature 12  Feature 13
# 0    0.328173    0.775977
# 1   -0.033298   -0.038949
# 2    0.049215   -0.305507
# ...

# %% [markdown]
# Sebelum menentukan n komponen pada PCA, akan dilihat menggunakan *bar chart* berikut berapa komponen yang mengandung sebagian besar varians data.

# %%
# Plot untuk menentukan kompenen yang mengandung varians dari data
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color="#8DC3A7")
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
plt.show()

# %% [markdown]
# Berdasarkan plot di atas, dapat disimpulkan bahwa 2 komponen pertama mengandung sebagian besar varians dari data.
#
# Dibuat modul PCA dengan `n_components` = 0.95. Ini akan membantu pemilihan jumlah komponen sambil mempertahankan 95% variabilitas dalam data, atau dapat juga mendukung pernyataan sebelumnya, apakah 2 kompenen mengandung sebagian besar variabilitas dari data.

# %%
pca095 = PCA(n_components=0.95)
principal_component095 = pca095.fit_transform(X)
principal_component095
# Out:
# array([[ 0.32195413, -2.26271834, -0.77528775, ..., -0.23467744,
#         -0.31761897,  0.11757997],
#        [-2.74901897,  1.02933313,  1.01090674, ..., -0.08895642,
#          0.70188139,  0.10717084],
#        [ 0.2277167 ,  1.12377208,  1.7949288 , ...,  0.24561727,
#         -0.35039102, -0.24718477],
#        ...,
#        [ 1.07118717, -3.15130394, -2.01473808, ..., -0.37533298,
#          0.20181961,  0.36127618],
#        [-1.59248409, -4.10907426, -1.15124969, ...,  0.12491652,
#          0.70948482,  0.62540099],
#        [-0.8575344 , -1.58407504, -0.02822131, ..., -0.12843805,
#         -0.36010109, -0.19137933]])

# %%
# Membuat dataframe dari kompenen utama yang sudah dibuat
cols = ["Principal Component "+str(i) for i in range(principal_component095.shape[1])]
df_pca_component095 = pd.DataFrame(data = principal_component095, columns = cols)
df_pca_component095.head()
# Out:
#    Principal Component 0  Principal Component 1  Principal Component 2  \
# 0               0.321954              -2.262718              -0.775288
# 1              -2.749019               1.029333               1.010907
# 2               0.227717               1.123772               1.794929
# 3              -1.161755              -1.552297               0.015311
# 4              -0.884173              -1.055298              -0.175703
#
#    Principal Component 3  Principal Component 4  Principal Component 5  \
# 0              -1.027829               0.090916              -0.317261
# 1               0.203129              -1.365147              -0.214327
# 2              -1.537572               2.122744              -0.323820
# 3              -1.160487               1.549467               2.157392
# 4              -1.474068               0.456975              -1.351414
#
#    Principal Component 6  Principal Component 7  Principal Component 8  \
# ...

# %% [markdown]
# Selanjutnya akan dibuat model PCA baru dengan jumlah kompenen sebanyak 2.

# %%
pca2 = PCA(n_components=2)
principal_comp = pca2.fit_transform(X)
principal_comp
# Out:
# array([[ 0.32195419, -2.26271841],
#        [-2.74901896,  1.02933316],
#        [ 0.22771659,  1.12377176],
#        ...,
#        [ 1.07118729, -3.15130351],
#        [-1.59248392, -4.10907378],
#        [-0.85753449, -1.58407528]])

# %%
# Membuat dataframe
df_pca2 = pd.DataFrame(data = principal_comp, columns = ["Principal Component 1", "Principal Component 2"])
df_pca2.head()
# Out:
#    Principal Component 1  Principal Component 2
# 0               0.321954              -2.262718
# 1              -2.749019               1.029333
# 2               0.227717               1.123772
# 3              -1.161755              -1.552298
# 4              -0.884174              -1.055299

# %%
# Menambahkan kolom klaster

df_pca2['Cluster'] = labels
df_pca2.head()
# Out:
#    Principal Component 1  Principal Component 2  Cluster
# 0               0.321954              -2.262718        1
# 1              -2.749019               1.029333        0
# 2               0.227717               1.123772        1
# 3              -1.161755              -1.552298        0
# 4              -0.884174              -1.055299        0

# %% [markdown]
# Selanjutnya, melakukan visualisasi dari 8950 sampel di sepanjang sumbu principal component 1 dan principal component 2

# %%
colors = {0: 'yellow',
          1: 'green'
         }

names = {0: 'Cluster 0', 
         1: 'Cluster 1'
        }

df_ = pd.DataFrame({'x':df_pca2["Principal Component 1"], 'y':df_pca2["Principal Component 2"], 'label':labels}) 
groups = df_.groupby('label')

fig, ax = plt.subplots(figsize=(15, 8)) 

for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=5,
            color=colors[name],label=names[name], mec='none')
    ax.set_aspect('auto')
    ax.tick_params(axis='x',which='both',bottom='off',top='off',labelbottom='off')
    ax.tick_params(axis= 'y',which='both',left='off',top='off',labelleft='off')
    
ax.legend()
ax.set_title("Segmentasi Pengguna Kartu Kredit berdasarkan Transaksi", fontsize=20)
plt.show()

# %% [markdown]
# ## DBScan

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=3,min_samples=6)
dfdbscan_df_dbscan= dbscan.fit(data_scaled)
y_dbscan_pred = dbscan.labels_
y_dbscan_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
dbscan_df = pd.DataFrame(df,columns = df.columns)
dbscan_df['CLUSTERS'] = y_dbscan_pred
dbscan_df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 0  3.735304           0.818182   4.568506                4.568506
# 1  8.071989           0.909091   0.000000                0.000000
# 2  7.822504           1.000000   6.651791                0.000000
# 3  7.419183           0.636364   7.313220                0.000000
# 4  6.707735           1.000000   2.833213                0.000000
#
#    CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0      0.000000                    0.000000                          0.083333
# 1      8.770896                    0.000000                          0.000000
# 2      0.000000                    0.693147                          0.000000
# 3      5.331694                    0.080042                          0.000000
# 4      0.000000                    0.080042                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  PURCHASES_TRX  PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# ...

# %%
dbscan_df.tail()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  INSTALLMENTS_PURCHASES  \
# 8945  3.384170           1.000000   5.677165                5.677165
# 8946  3.004851           1.000000   5.707110                5.707110
# 8947  3.194529           0.833333   4.979489                4.979489
# 8948  2.671218           0.833333   0.000000                0.000000
# 8949  5.923475           0.666667   6.997824                0.000000
#
#       CASH_ADVANCE  ONEOFF_PURCHASES_FREQUENCY  \
# 8945      0.000000                    0.000000
# 8946      0.000000                    0.000000
# 8947      0.000000                    0.000000
# 8948      3.625907                    0.000000
# 8949      4.852343                    0.510826
#
#       PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  PURCHASES_TRX  \
# 8945                          0.833333                0.000000              6
# 8946                          0.833333                0.000000              6
# ...

# %%
dbscan_df['CLUSTERS'].value_counts()
# Out:
#  0    8933
# -1      17
# Name: CLUSTERS, dtype: int64

# %%
Y = dbscan_df[['BALANCE','PURCHASES']].to_numpy()

# %%
dbscan = DBSCAN(eps=0.075,min_samples=2)
dbscan.fit(Y)
y_dbscan_pred = dbscan.labels_
y_dbscan_pred
# Out:
# array([  0,   1,   2, ..., 359, 341,   2], dtype=int64)

# %%
plt.figure(figsize=(10,10))
plt.scatter(dbscan_df['BALANCE'],dbscan_df['PURCHASES'],c=dbscan_df['CLUSTERS'])
plt.title('DBSCAN Clustering',fontsize=20)
plt.xlabel('Feature 1',fontsize=14)
plt.ylabel('Feature 2',fontsize=14)
plt.show()

# Save Plot
plt.savefig("dbscan_graph.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %% [markdown]
# ## Model Inference

# %% [markdown]
# Untuk menguji keakuratan model, dilakukan model inference untuk menguji model dengan data di luar data yang tersedia.

# %% [markdown]
# Misal terdapat pengguna kartu kredit dengan catatan transaksi sebagai berikut:
# - BALANCE : 1320
# - BALANCE_FREQUENCY : 0.60
# - PURCHASES : 450
# - INSTALLMENTS_PURCHASES = 50
# - CASH_ADVANCE = 50
# - oneoff_purchases_frq: 1.0
# - INSTALLMENTS_PURCHASES_FREQUENCY = 0.3
# - CASH_ADVANCE_FREQUENCY = 0.5
# - PURCHASES_TRX = 10
# - CREDIT_LIMIT = 3500
# - PAYMENTS = 1000
# - MINIMUM_PAYMENTS = 100
# - PRC_FULL_PAYMENT = 0.02
# - TENURE = 12
#
# Pengguna ini akan termasuk dalam kelompok klaster berapa?

# %%
balance = float(input('Balance:'))
balance_frq = float(input('Balance Frequency:'))
purchases = float(input('Purchases Amount:'))
installment_purchases = float(input('Installment Purchases Amount:'))
cash_advance = float(input('Cash Advance Amount:'))
oneoff_purchases_frq = float(input('ONEOFF Purchases Frequency:'))
installment_purchases_frq = float(input('Installment Purchases Frequency:'))
cash_advance_frq = float(input('Cash Advance Frequency:'))
purchases_trx = float(input('Number of Purchases Transaction:'))
credit_limit = float(input('Credit Limit Amount:'))
payments = float(input('Payment Amount:'))
minimum_payments = float(input('Minimum Payments Amount:'))
prc_full_payments = float(input('Percentage of Full Payments:'))
tenure = float(input('Tenure:'))

val = [balance, balance_frq, purchases, installment_purchases, 
       cash_advance, oneoff_purchases_frq, installment_purchases_frq,
       cash_advance_frq, purchases_trx, credit_limit, payments, minimum_payments, prc_full_payments, tenure]
val = scaler.transform([val])

print('Input values:', val)

val_predict = kmeans.predict(val)

if val_predict == 0:
    print('Pengguna termasuk ke dalam klaster {}, dengan karakteristik\nPengguna dengan limit kredit dengan rata rata 800 dan jarang melakukan transaksi pembayaran dan pembelian'.format(val_predict))
elif val_predict == 1:
    print('Pengguna termasuk ke dalam klaster {}, dengan karakteristik\nPengguna dengan limit kredit dengan rata-rata 1000 dan sering melakukan transaksi pembayaran dan pembelian'.format(val_predict))
else:
    print('Pengguna tidak termasuk dalam klaster manapun')
# Out:
# Balance:1320
# Balance Frequency:0.6
# Purchases Amount:450
# Installment Purchases Amount:50
# Cash Advance Amount:50
# ONEOFF Purchases Frequency:1.0
# Installment Purchases Frequency:0.3
# Cash Advance Frequency:0.5
# Number of Purchases Transaction:10
# Credit Limit Amount:3500
# Payment Amount:1000
# Minimum Payments Amount:100
# Percentage of Full Payments:0.02
# Tenure:12
# Input values: [[ 6.52615079e+02 -1.17045813e+00  1.52603621e+02  1.51315633e+01
#    1.30901895e+01  3.88305047e+00 -1.62136877e-01  2.46630448e+00
#   -1.89482743e-01  2.19478117e+03  4.72523036e+03  6.61179039e+01
#   -5.03996919e+00  4.76483064e+00]]
# Pengguna termasuk ke dalam klaster [1], dengan karakteristik
# Pengguna dengan limit kredit rata-rata dan tidak banyak melakukan transaksi maupun tarik tunai kartu kredit

# %% [markdown]
# ## Save Model

# %% [markdown]
# Pada tahap menyimpan serta membaca data ke dalam/dari sebuah file dapat digunakannya sebuah modul pickle.

# %%
import pickle

# %% [markdown]
# ### Model KMeans Clustering

# %%
pickle.dump(kmeans, open('kmeans_model.pkl','wb'))

# %% [markdown]
# ### Model DBSCAN

# %%
pickle.dump(dbscan, open('model_dbscan.pkl','wb'))

# %% [markdown]
# ## Conclusion
#
# Credit Card Dataset for Clustering memiliki 9000 records dan 18 atribut. Setelah tahap data preprocessing dan EDA dilakukan, terdapat 14 atribut dan 8950 records yang dianggap paling relevan terhadap analisis dan akan digunakan untuk melakukan clustering.
#
# Dalam projek ini, dataset dikelompokkan (clustering) menggunakan metode KMeans Clustering, PCA, DBSCAN. Sebelum dilalukan clustering, jumlah optimal cluster ditentukan menggunakan Elbow Method dan Shiloutte Score. Dari kedua metode tersebut, didapatkan hasil jumlah cluster yang paling optimal adalah 2, yaitu Cluster 0 dan Cluster 1.
#
# Berdasarkan hasil analisa masing - masing cluster memiliki karakteristik, sebagai berikut
#
# **Cluster 0:**
# - Jumlah pengguna sebanyak 3630
# - Nilai balance frequency lebih kecil daripada cluster 1, yang berarti saldo pengguna lebih jarang diupdate
# - Pengguna lebih jarang melakukan purchases atau pembelian bahkan lebih 2000 pengguna tidak melakukan pembelian
# - Jumlah pengguna yang melakukan payment atau pembayaran kartu kredit adalah kurang dari 1300 pengguna
# - Pengguna yang membayar tenure berjumlah kurang lebih 2500 pengguna
# - Credit limit pengguna lebih rendah daripada cluster 1, rata - rata ada diangka 800
#
# **Cluster 1:**
# - Jumlah pengguna sebanyak 5320, lebih banyak daripada cluster 0
# - Nilai balance frequency lebih besar daripada cluster 0
# - Pengguna sering melakukan purchases atau pembelian
# - Jumlah pengguna yang melakukan payment atau pembayaran kartu kredit adalah kurang dari 2000 pengguna
# - Pengguna yang membayar tenure berjumlah kurang lebih 5000 pengguna
# - Credit limit pengguna lebih tinggi daripada cluster 0, rata - rata ada diangka 1000 ke atas

# %% [markdown]
# ## FINISH
# - FIRYA FATIN RAHMADANTI PYTN KS06-005
# - JUNINDA MEGARISMATIO PAKPAHAN PYTN KS06-008
#
# ## TERIMA KASIH
